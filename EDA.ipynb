# %% [markdown]
# # Audio Dataset Exploration
#
# This notebook explores the audio-caption dataset from Kaggle.

# %%
# Import the dataloader
import sys
sys.path.append('.')

# Reload modules to pick up any changes
import importlib
if 'data.dataloader' in sys.modules:
    importlib.reload(sys.modules['data.dataloader'])

from data.dataloader import get_dataloader, AudioCaptionDataset
import matplotlib.pyplot as plt
import numpy as np

# %%
# Configuration: Set USE_SUBSET=True for local testing, False for full dataset on HPC
USE_SUBSET = True
SUBSET_SIZE = 100  # Number of samples to use for local testing

if USE_SUBSET:
    print(f"🔧 LOCAL MODE: Using subset of {SUBSET_SIZE} samples for testing")
else:
    print("🚀 HPC MODE: Using full dataset")
# Out:
# 🔧 LOCAL MODE: Using subset of 100 samples for testing

# %%
# Load the dataloader to explore batches
dataloader = get_dataloader(batch_size=1, shuffle=False, subset_size=SUBSET_SIZE if USE_SUBSET else None)
dataset = dataloader.dataset
print(f"Dataset size: {len(dataset)}")
print(f"\nDataFrame columns: {dataset.df.columns.tolist()}")
print(f"\nFirst 5 rows:")
print(dataset.df.head())
# Out:
# Resuming download from 335544320 bytes (1192605731 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/mmoreaux/environmental-sound-classification-50?dataset_version_number=15 (335544320/1528150051) bytes left.
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/mmoreaux/environmental-sound-classification-50?dataset_version_number=15 (335544320/1528150051) bytes left.
#  28%|██▊       | 402M/1.42G [01:11<15:21, 1.20MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Load the dataloader to explore batches
# ----> 2 dataloader = get_dataloader(batch_size=1, shuffle=False, subset_size=SUBSET_SIZE if USE_SUBSET else None)
#       3 dataset = dataloader.dataset
#       4 print(f"Dataset size: {len(dataset)}")
#
# File c:\Users\Besitzer\OneDrive\Dokumente\CBS_Copenhagen\Semester\WS2025\AdvCV\Final Exam\Adv.-CV-Final-Exam\data\dataloader.py:71, in get_dataloader(batch_size, shuffle, num_workers, subset_size)
#      68 shuffle = shuffle if shuffle is not None else config.SHUFFLE
#      69 num_workers = num_workers or config.NUM_WORKERS
# ---> 71 dataset = AudioCaptionDataset(subset_size=subset_size)
#      72 return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers)
#
# File c:\Users\Besitzer\OneDrive\Dokumente\CBS_Copenhagen\Semester\WS2025\AdvCV\Final Exam\Adv.-CV-Final-Exam\data\dataloader.py:23, in AudioCaptionDataset.__init__(self, subset_size)
#      16 """
#      17 Load audio-caption dataset using configuration.
#      18
#      19 Args:
#      20     subset_size: If provided, only use the first N samples (for local testing)
#      21 """
#      22 # Download dataset if not already downloaded
# ---> 23 dataset_path = kagglehub.dataset_download(config.DATASET_NAME)
#      25 # Load CSV with captions
#      26 csv_path = os.path.join(dataset_path, config.CSV_FILE)
#
# File c:\Users\Besitzer\OneDrive\Dokumente\CBS_Copenhagen\Semester\WS2025\AdvCV\Final Exam\Adv.-CV-Final-Exam\venv\Lib\site-packages\kagglehub\datasets.py:43, in dataset_download(handle, path, force_download)
#      41 h = parse_dataset_handle(handle)
#      42 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 43 path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      44 return path
#
# File c:\Users\Besitzer\OneDrive\Dokumente\CBS_Copenhagen\Semester\WS2025\AdvCV\Final Exam\Adv.-CV-Final-Exam\venv\Lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File c:\Users\Besitzer\OneDrive\Dokumente\CBS_Copenhagen\Semester\WS2025\AdvCV\Final Exam\Adv.-CV-Final-Exam\venv\Lib\site-packages\kagglehub\resolver.py:29, in Resolver.__call__(self, handle, path, force_download)
#      15 def __call__(
#      16     self, handle: T, path: Optional[str] = None, *, force_download: Optional[bool] = False
#      17 ) -> tuple[str, Optional[int]]:
#      18     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      19
#      20     Args:
#    (...)     27         Some cases where version number might be missing: Competition datasource, API-based models.
#      28     """
# ---> 29     path, version = self._resolve(handle, path, force_download=force_download)
#      31     # Note handles are immutable, so _resolve() could not have altered our reference
#      32     register_datasource_access(handle, version)
#
# File c:\Users\Besitzer\OneDrive\Dokumente\CBS_Copenhagen\Semester\WS2025\AdvCV\Final Exam\Adv.-CV-Final-Exam\venv\Lib\site-packages\kagglehub\http_resolver.py:130, in DatasetHttpResolver._resolve(self, h, path, force_download)
#     127 os.makedirs(os.path.dirname(archive_path), exist_ok=True)
#     129 # First, we download the archive.
# --> 130 api_client.download_file(url_path, archive_path, h)
#     132 _extract_archive(archive_path, out_path)
#     134 # Delete the archive
#
# File c:\Users\Besitzer\OneDrive\Dokumente\CBS_Copenhagen\Semester\WS2025\AdvCV\Final Exam\Adv.-CV-Final-Exam\venv\Lib\site-packages\kagglehub\clients.py:214, in KaggleApiV1Client.download_file(self, path, out_file, resource_handle, cached_path, extract_auto_compressed_file)
#     206     with requests.get(
#     207         response.url,  # URL after redirection
#     208         stream=True,
#    (...)    211         headers={"Range": f"bytes={size_read}-"},
#     212     ) as resumed_response:
#     213         logger.info(f"Resuming download from {url} ({size_read}/{total_size}) bytes left.")
# --> 214         _download_file(resumed_response, out_file, size_read, total_size, hash_object)
#     215 else:
#     216     logger.info(f"Downloading from {url}...")
#
# File c:\Users\Besitzer\OneDrive\Dokumente\CBS_Copenhagen\Semester\WS2025\AdvCV\Final Exam\Adv.-CV-Final-Exam\venv\Lib\site-packages\kagglehub\clients.py:276, in _download_file(response, out_file, size_read, total_size, hash_object)
#     274 with tqdm(total=total_size, initial=size_read, unit="B", unit_scale=True, unit_divisor=1024) as progress_bar:
#     275     with open(out_file, open_mode) as f:
# --> 276         for chunk in response.iter_content(CHUNK_SIZE):
#     277             f.write(chunk)
#     278             if hash_object:
#
# File c:\Users\Besitzer\OneDrive\Dokumente\CBS_Copenhagen\Semester\WS2025\AdvCV\Final Exam\Adv.-CV-Final-Exam\venv\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File c:\Users\Besitzer\OneDrive\Dokumente\CBS_Copenhagen\Semester\WS2025\AdvCV\Final Exam\Adv.-CV-Final-Exam\venv\Lib\site-packages\urllib3\response.py:1091, in HTTPResponse.stream(self, amt, decode_content)
#    1089 else:
#    1090     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1091         data = self.read(amt=amt, decode_content=decode_content)
#    1093         if data:
#    1094             yield data
#
# File c:\Users\Besitzer\OneDrive\Dokumente\CBS_Copenhagen\Semester\WS2025\AdvCV\Final Exam\Adv.-CV-Final-Exam\venv\Lib\site-packages\urllib3\response.py:980, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     977     if len(self._decoded_buffer) >= amt:
#     978         return self._decoded_buffer.get(amt)
# --> 980 data = self._raw_read(amt)
#     982 flush_decoder = amt is None or (amt != 0 and not data)
#     984 if not data and len(self._decoded_buffer) == 0:
#
# File c:\Users\Besitzer\OneDrive\Dokumente\CBS_Copenhagen\Semester\WS2025\AdvCV\Final Exam\Adv.-CV-Final-Exam\venv\Lib\site-packages\urllib3\response.py:904, in HTTPResponse._raw_read(self, amt, read1)
#     901 fp_closed = getattr(self._fp, "closed", False)
#     903 with self._error_catcher():
# --> 904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     905     if amt is not None and amt != 0 and not data:
#     906         # Platform-specific: Buggy versions of Python.
#     907         # Close the connection when no data is returned
#    (...)    912         # not properly close the connection in all cases. There is
#     913         # no harm in redundantly calling close.
#     914         self._fp.close()
#
# File c:\Users\Besitzer\OneDrive\Dokumente\CBS_Copenhagen\Semester\WS2025\AdvCV\Final Exam\Adv.-CV-Final-Exam\venv\Lib\site-packages\urllib3\response.py:887, in HTTPResponse._fp_read(self, amt, read1)
#     884     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     885 else:
#     886     # StringIO doesn't like amt=None
# --> 887     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:473, in HTTPResponse.read(self, amt)
#     470 if self.length is not None and amt > self.length:
#     471     # clip the read to the "end of response"
#     472     amt = self.length
# --> 473 s = self.fp.read(amt)
#     474 if not s and amt:
#     475     # Ideally, we would raise IncompleteRead if the content-length
#     476     # wasn't satisfied, but it might break compatibility.
#     477     self._close_conn()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Get a single sample
waveform, sample_rate, caption = dataset[0]
print(f"Waveform shape: {waveform.shape}")
print(f"Sample rate: {sample_rate}")
print(f"Caption: {caption}")

# %%
# Visualize the first audio sample
plt.figure(figsize=(12, 4))
plt.plot(waveform.t().numpy())
plt.title(f"Audio Waveform - {caption}")
plt.xlabel("Sample")
plt.ylabel("Amplitude")
plt.show()

# %%
# Create a DataLoader and iterate through batches
dataloader = get_dataloader(batch_size=4, shuffle=False, subset_size=SUBSET_SIZE if USE_SUBSET else None)

# Get one batch
for batch_waveforms, batch_sample_rates, batch_captions in dataloader:
    print(f"Batch size: {len(batch_captions)}")
    print(f"Waveforms shape: {batch_waveforms.shape}")
    print(f"Captions: {batch_captions}")
    break  # Just look at first batch

# %%
# Explore caption distribution
print("Caption distribution:")
print(dataset.df[dataset.df.columns[-1]].value_counts())
